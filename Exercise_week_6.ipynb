# %% [markdown]
# <a href="https://colab.research.google.com/github/irawan09/data_mining_class/blob/main/Exercise_week_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# custom data transform for removing columns with few unique values
import numpy as np
from numpy import unique
from pandas import read_csv
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import LabelEncoder

# load a dataset
def load_dataset(path):
    # load the dataset
    df = read_csv(path, header=None)
    data = df.values
    # split data into inputs and outputs
    X, y = data[:, :-1], data[:, -1]
    # minimally prepare dataset
    X = X.astype('float')
    y = LabelEncoder().fit_transform(y.astype('str'))
    return X, y

# define the location of the dataset
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/oil-spill.csv'
# load the dataset
X, y = load_dataset(url)

print(X.shape, y.shape)
# Out:
# (937, 49) (937,)

# %%
df = read_csv(url, header=None)
df
# Out:
#       0      1        2       3    4   ...  45        46     47    48  49
# 0      1   2558  1506.09  456.63   90  ...   0  33243.19  65.74  7.95   1
# 1      2  22325    79.11  841.03  180  ...   0  51572.04  65.73  6.26   0
# 2      3    115  1449.85  608.43   88  ...   1  31692.84  65.81  7.84   1
# 3      4   1201  1562.53  295.65   66  ...   1  37696.21  65.67  8.07   1
# 4      5    312   950.27  440.86   37  ...   0  29038.17  65.66  7.35   0
# ..   ...    ...      ...     ...  ...  ...  ..       ...    ...   ...  ..
# 932  200     12    92.42  364.42  135  ...   0   2593.50  65.85  6.39   0
# 933  201     11    98.82  248.64  159  ...   0   4361.25  65.70  6.53   0
# 934  202     14    25.14  428.86   24  ...   0   2153.05  65.91  6.12   0
# 935  203     10    96.00  451.30   68  ...   0   2421.43  65.97  6.32   0
# 936  204     11     7.73  235.73  135  ...   0   3782.68  65.65  6.26   0
#
# [937 rows x 50 columns]

# %%
def remove_unique(data):
    result_index = np.where(data <= 1)
    erase = np.delete(data, result_index, axis=1)
    unq = np.unique(erase)
    print (data)

    return data

# remove_unique(X)


def remove_outliers(data):
    mean = np.mean(data, axis=1)
    std = np.std(data, axis=1)
    batas_kiri = mean-3*std
    batas_kanan =  mean+3*std
    print("lower endpoint : ",batas_kiri)
    print("upper endpoint : ",batas_kanan)
    print("-"*100)
    kiri_index = np.where(data < batas_kiri)
    kiri_erase = np.delete(data, kiri_index)
    kanan_index = np.where(data > batas_kanan)
    kanan_erase = np.delete(data, kanan_index)
    print(data)

    return data

remove_outliers(X)
# Out:
# lower endpoint :  [-2.57953828e+06 -2.25289360e+07 -1.15614361e+05 -1.21017336e+06
#  -3.13991586e+05 -5.49136868e+04 -1.16585944e+05 -5.95760492e+04
#  -1.88975997e+05 -6.48446414e+04 -6.19543439e+04 -3.31580051e+05
#  -3.26266371e+06 -2.35946009e+06 -2.99705538e+06 -3.18277138e+06
#  -1.15792996e+07 -1.04270992e+06 -1.04356200e+06 -4.89381518e+06
#  -2.92473949e+06 -1.66915487e+06 -2.68710583e+06 -9.43893697e+05
#  -4.89864864e+05 -8.58098913e+05 -1.40781947e+06 -2.52465490e+06
#  -6.52416595e+04 -1.92265435e+05 -3.65703073e+05 -4.88898838e+05
#  -6.54043831e+05 -4.08063438e+05 -8.56000902e+05 -2.30534024e+05
#  -8.14176767e+04 -1.16652454e+06 -1.24733469e+05 -8.43604092e+04
#  -2.10399290e+05 -3.52718072e+05 -4.97914498e+05 -2.93870538e+05
#  -1.02552017e+05 -6.26759075e+05 -6.82424463e+04 -6.34236670e+05
#  -9.13670882e+04 -3.57755332e+05 -9.84990263e+04 -4.13135303e+05
#  -9.85441989e+04 -9.25291499e+04 -3.04270139e+05 -9.34623633e+04
# ...
